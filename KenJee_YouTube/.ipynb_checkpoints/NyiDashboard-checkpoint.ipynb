# %%
#import libs
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import streamlit as st
from datetime import datetime

# %%
#load data
df_agg=pd.read_csv("Project_data/Aggregated_Metrics_By_Video.csv").iloc[1:,:]
df_agg_sub=pd.read_csv("Project_data/Aggregated_Metrics_By_Country_And_Subscriber_Status.csv")
df_comment=pd.read_csv("Project_data/All_Comments_Final.csv")
df_datetime=pd.read_csv("Project_data/Video_Performance_Over_Time.csv")

# %%
#feature engineering
#fix the columns for proper looking
df_agg.columns = ['Video','Video title','Video publish time','Comments added','Shares','Dislikes','Likes',
                      'Subscribers lost','Subscribers gained','RPM(USD)','CPM(USD)','Average % viewed','Average view duration',
                      'Views','Watch time (hours)','Subscribers','Your estimated revenue (USD)','Impressions','Impressions ctr(%)']


#change dtypes
df_agg["Video publish time"]=pd.to_datetime(df_agg["Video publish time"])
df_agg["Average view duration"]=df_agg["Average view duration"].apply(lambda x: datetime.strptime(x,"%H:%M:%S"))
df_agg["Average duration sec"]=df_agg["Average view duration"].apply(lambda x: x.second+x.minute*60+x.hour*360)


#add some necessary features
df_agg["Engagement_ratio"]=(df_agg["Comments added"]+df_agg["Shares"]+df_agg["Dislikes"]+df_agg["Likes"])/df_agg["Views"]
df_agg["ViewsPerSubscriber_gained"]=df_agg["Views"]/df_agg["Subscribers gained"]#number of views to gain subsriber

# %%
df_agg
# Out:
#            Video                                        Video title  \
# 1    4OZip0cgOho  How I Would Learn Data Science (If I Had to St...
# 2    78LjdAAw0wA                  100K Channel Update + AMA Stream!
# 3    hO_YKK_0Qck  Uber Driver to Machine Learning Engineer in 9 ...
# 4    uXLnbdHMf8w          Why I'm Starting Data Science Over Again.
# 5    Xgg7dIKys9E  Interview with the Director of AI Research @ N...
# ..           ...                                                ...
# 219  FBgs-BSTIJE                    Demystifying Data Science Roles
# 220  Yr5T3T4tq-g  Most Data Science Hopefuls Overlook This Impor...
# 221  j-Z-je6K4Yg                   IT'S NOT TOO LATE TO LEARN CODE!
# 222  5jntoZX-Tc8  NASA Physicist Turned Data Scientist (Tim Bowl...
# 223  5p73cIRYCZg                     ProjectDemoCSC478_UFCFightData
#
#     Video publish time  Comments added  Shares  Dislikes  Likes  \
# 1           2020-05-08             907    9583       942  46903
# 2           2020-11-12             412       4         4    130
# 3           2020-07-16             402     152        15    881
# 4           2020-08-29             375     367        22   2622
# 5           2020-08-05             329     118        15    590
# ..                 ...             ...     ...       ...    ...
# 219         2018-11-30               3       5         1     48
# 220         2019-05-25               3       0         0     44
# 221         2018-12-18               3       1         0     35
# 222         2019-05-05               2       5         0     38
# 223         2017-06-06               0       2         0      1
#
#      Subscribers lost  Subscribers gained  RPM(USD)  ...  \
# 1                 451               46904     6.353  ...
# 2                  15                  12     2.668  ...
# 3                   9                 198     9.516  ...
# 4                  40                1957     3.143  ...
# 5                  11                 161     2.973  ...
# ..                ...                 ...       ...  ...
# 219                 1                   8     5.218  ...
# 220                 0                   5     3.374  ...
# 221                 0                   7     3.784  ...
# 222                 0                   3     2.651  ...
# 223                 0                   0     0.050  ...
#
#      Average view duration    Views Watch time (hours)  Subscribers  \
# 1      1900-01-01 00:03:09  1253559         65850.7042        46453
# 2      1900-01-01 00:05:14     2291           200.2966           -3
# 3      1900-01-01 00:10:21    21350          3687.3387          189
# 4      1900-01-01 00:02:36    49564          2148.3110         1917
# 5      1900-01-01 00:04:37    13429          1034.3945          150
# ..                     ...      ...                ...          ...
# 219    1900-01-01 00:03:28      978            56.5930            7
# 220    1900-01-01 00:02:06      548            19.2752            5
# 221    1900-01-01 00:01:52      721            22.5450            7
# 222    1900-01-01 00:03:09     1094            57.6363            3
# 223    1900-01-01 00:01:04       60             1.0684            0
#
#      Your estimated revenue (USD)  Impressions  Impressions ctr(%)  \
# 1                        7959.533     26498799                3.14
# 2                           6.113       188318                0.72
# 3                         202.963       442334                2.53
# 4                         155.779       521185                4.01
# 5                          39.920       210876                3.38
# ..                            ...          ...                 ...
# 219                         5.103        26202                2.24
# 220                         1.849        21780                1.61
# 221                         2.728        18635                2.65
# 222                         2.900        34642                1.99
# 223                         0.003          365               11.51
#
#      Average duration sec  Engagement_ratio  ViewsPerSubscriber_gained
# 1                     189          0.046536                  26.726057
# 2                     314          0.240070                 190.916667
# 3                     621          0.067916                 107.828283
# 4                     156          0.068316                  25.326520
# 5                     277          0.078338                  83.409938
# ..                    ...               ...                        ...
# 219                   208          0.058282                 122.250000
# 220                   126          0.085766                 109.600000
# 221                   112          0.054092                 103.000000
# 222                   189          0.041133                 364.666667
# 223                    64          0.050000                        inf
#
# [223 rows x 22 columns]
